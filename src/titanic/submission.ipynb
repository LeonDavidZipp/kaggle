# %%
import polars as pl
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV

from xgboost import XGBClassifier
from skopt import BayesSearchCV
import skopt.space as ss

import sys
sys.path.append("/Users/leon/Desktop/kaggle/")
import src.titanic.transformer_impl as ti

# %% [markdown]
# # Data Loading & Transformation

# %%
df = pl.read_csv("./data/train.csv")
test_df = pl.read_csv("./data/test.csv")

# %% [markdown]
# ## Training Data Transformations

# %%
tfr = ti.TitanicTransformer()
data = tfr.transform(df)
X = data[:, :-1]
y = data[:, -1].ravel()
X.shape
# Out:
# (891, 27)

# %% [markdown]
# ## Test Data Transformations

# %%
X_test = tfr.transform(test_df)

# %% [markdown]
# # Best Model

# %%
from sklearn.model_selection import train_test_split
Xtr, Xte, ytr, yte = train_test_split(X, y, shuffle=True)
rf_clf2 = RandomForestClassifier()
rf_clf2.fit(Xtr, ytr)
rf_clf2.score(Xte, yte)
# Out:
# 0.820627802690583

# %%
from sklearn.model_selection import GridSearchCV

rf_clf = RandomForestClassifier()
params = [
	{"n_estimators": [99, 100, 101], "max_features": [10, 11, 12]}
]

res = GridSearchCV(
	estimator=rf_clf,
	param_grid=params,
	cv=5,
	scoring="accuracy"
).fit(Xtr, ytr)

# %%
final_model = RandomForestClassifier(
	n_estimators=11,
	max_features=11
).fit(X, y)

# %%
solutions = {}

for row in test_df.iter_rows(named=True):
	id = row["PassengerId"]
	x = tfr.transform(pl.DataFrame(row))
	solutions[id] = final_model.predict(x)

with open(file="./submission.csv", mode="w") as f:
	f.write("PassengerId,Survived\n")
	for k in solutions.keys():
		f.write(f"{k},{int(solutions[k][0])}\n")

# %%
model = XGBClassifier()

spaces = {
	"n_estimators": ss.Integer(1000, 1500),
	"learning_rate": ss.Real(0.01, 0.2)
}

sss = StratifiedShuffleSplit(n_splits=1, random_state=42)
for train_index, test_index in sss.split(X, y):
	X_train, X_test = X[train_index], X[test_index]
	y_train, y_test = y[train_index], y[test_index]

	opt = BayesSearchCV(
		estimator=model,
		search_spaces=spaces,
		cv=5,
	).fit(X_train, y_train)

# %%
sss = StratifiedShuffleSplit(n_splits=1, random_state=42)
for train_index, test_index in sss.split(X, y):
	X_train, X_test = X[train_index], X[test_index]
	y_train, y_test = y[train_index], y[test_index]
	model2 = XGBClassifier(
		n_estimators=1100,
		early_stopping_rounds=50,
		learning_rate=0.01
	).fit(
		X_train,
		y_train,
		eval_set=[(X_train, y_train), (X_test, y_test)],
		# verbose=True
	)
model2.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 sss = StratifiedShuffleSplit(n_splits=1, random_state=42)
# ----> 2 for train_index, test_index in sss.split(X, y):
#       3 	X_train, X_test = X[train_index], X[test_index]
#       4 	y_train, y_test = y[train_index], y[test_index]
#
# NameError: name 'X' is not defined

# %%
sss = StratifiedShuffleSplit(n_splits=1, random_state=42)
for train_index, test_index in sss.split(X, y):
	X_train, X_test = X[train_index], X[test_index]
	y_train, y_test = y[train_index], y[test_index]
	model3 = XGBClassifier(
		n_estimators=1100,
		early_stopping_rounds=50,
		learning_rate=0.01
	).fit(
		X_train,
		y_train,
		eval_set=[(X_train, y_train), (X_test, y_test)],
		# verbose=True
	)
model3.score(X_test, y_test)
# Out:
# [0]	validation_0-logloss:0.66081	validation_1-logloss:0.66417
# [1]	validation_0-logloss:0.65609	validation_1-logloss:0.66012
# [2]	validation_0-logloss:0.65146	validation_1-logloss:0.65615
# [3]	validation_0-logloss:0.64692	validation_1-logloss:0.65227
# [4]	validation_0-logloss:0.64248	validation_1-logloss:0.64847
# [5]	validation_0-logloss:0.63813	validation_1-logloss:0.64475
# [6]	validation_0-logloss:0.63386	validation_1-logloss:0.64110
# [7]	validation_0-logloss:0.62968	validation_1-logloss:0.63753
# [8]	validation_0-logloss:0.62558	validation_1-logloss:0.63404
# [9]	validation_0-logloss:0.62156	validation_1-logloss:0.63061
# [10]	validation_0-logloss:0.61761	validation_1-logloss:0.62726
# [11]	validation_0-logloss:0.61374	validation_1-logloss:0.62397
# [12]	validation_0-logloss:0.60995	validation_1-logloss:0.62075
# [13]	validation_0-logloss:0.60623	validation_1-logloss:0.61759
# [14]	validation_0-logloss:0.60257	validation_1-logloss:0.61449
# [15]	validation_0-logloss:0.59898	validation_1-logloss:0.61143
# [16]	validation_0-logloss:0.59546	validation_1-logloss:0.60844
# [17]	validation_0-logloss:0.59201	validation_1-logloss:0.60550
# [18]	validation_0-logloss:0.58861	validation_1-logloss:0.60263
# [19]	validation_0-logloss:0.58528	validation_1-logloss:0.59980
# [20]	validation_0-logloss:0.58201	validation_1-logloss:0.59702
# [21]	validation_0-logloss:0.57880	validation_1-logloss:0.59430
# [22]	validation_0-logloss:0.57564	validation_1-logloss:0.59163
# [23]	validation_0-logloss:0.57254	validation_1-logloss:0.58902
# [24]	validation_0-logloss:0.56949	validation_1-logloss:0.58644
# [25]	validation_0-logloss:0.56649	validation_1-logloss:0.58391
# [26]	validation_0-logloss:0.56355	validation_1-logloss:0.58143
# [27]	validation_0-logloss:0.56066	validation_1-logloss:0.57899
# [28]	validation_0-logloss:0.55782	validation_1-logloss:0.57662
# [29]	validation_0-logloss:0.55502	validation_1-logloss:0.57430
# [30]	validation_0-logloss:0.55228	validation_1-logloss:0.57200
# [31]	validation_0-logloss:0.54958	validation_1-logloss:0.56976
# [32]	validation_0-logloss:0.54693	validation_1-logloss:0.56754
# [33]	validation_0-logloss:0.54432	validation_1-logloss:0.56539
# [34]	validation_0-logloss:0.54174	validation_1-logloss:0.56332
# [35]	validation_0-logloss:0.53921	validation_1-logloss:0.56133
# [36]	validation_0-logloss:0.53672	validation_1-logloss:0.55934
# [37]	validation_0-logloss:0.53427	validation_1-logloss:0.55740
# [38]	validation_0-logloss:0.53187	validation_1-logloss:0.55545
# [39]	validation_0-logloss:0.52950	validation_1-logloss:0.55356
# [40]	validation_0-logloss:0.52717	validation_1-logloss:0.55174
# [41]	validation_0-logloss:0.52487	validation_1-logloss:0.54993
# [42]	validation_0-logloss:0.52261	validation_1-logloss:0.54817
# [43]	validation_0-logloss:0.52039	validation_1-logloss:0.54641
# [44]	validation_0-logloss:0.51820	validation_1-logloss:0.54470
# [45]	validation_0-logloss:0.51605	validation_1-logloss:0.54304
# [46]	validation_0-logloss:0.51393	validation_1-logloss:0.54146
# [47]	validation_0-logloss:0.51185	validation_1-logloss:0.53986
# [48]	validation_0-logloss:0.50980	validation_1-logloss:0.53834
# [49]	validation_0-logloss:0.50778	validation_1-logloss:0.53689
# [50]	validation_0-logloss:0.50579	validation_1-logloss:0.53533
# [51]	validation_0-logloss:0.50383	validation_1-logloss:0.53391
# [52]	validation_0-logloss:0.50187	validation_1-logloss:0.53233
# [53]	validation_0-logloss:0.49989	validation_1-logloss:0.53068
# [54]	validation_0-logloss:0.49793	validation_1-logloss:0.52905
# [55]	validation_0-logloss:0.49601	validation_1-logloss:0.52742
# [56]	validation_0-logloss:0.49411	validation_1-logloss:0.52585
# [57]	validation_0-logloss:0.49224	validation_1-logloss:0.52426
# [58]	validation_0-logloss:0.49041	validation_1-logloss:0.52271
# [59]	validation_0-logloss:0.48860	validation_1-logloss:0.52122
# [60]	validation_0-logloss:0.48681	validation_1-logloss:0.51971
# [61]	validation_0-logloss:0.48506	validation_1-logloss:0.51823
# [62]	validation_0-logloss:0.48335	validation_1-logloss:0.51694
# [63]	validation_0-logloss:0.48165	validation_1-logloss:0.51555
# [64]	validation_0-logloss:0.47997	validation_1-logloss:0.51414
# [65]	validation_0-logloss:0.47831	validation_1-logloss:0.51276
# [66]	validation_0-logloss:0.47669	validation_1-logloss:0.51140
# [67]	validation_0-logloss:0.47508	validation_1-logloss:0.51010
# [68]	validation_0-logloss:0.47348	validation_1-logloss:0.50883
# [69]	validation_0-logloss:0.47190	validation_1-logloss:0.50760
# [70]	validation_0-logloss:0.47034	validation_1-logloss:0.50648
# [71]	validation_0-logloss:0.46880	validation_1-logloss:0.50538
# [72]	validation_0-logloss:0.46729	validation_1-logloss:0.50430
# [73]	validation_0-logloss:0.46581	validation_1-logloss:0.50330
# [74]	validation_0-logloss:0.46436	validation_1-logloss:0.50220
# [75]	validation_0-logloss:0.46293	validation_1-logloss:0.50123
# [76]	validation_0-logloss:0.46150	validation_1-logloss:0.50012
# [77]	validation_0-logloss:0.46009	validation_1-logloss:0.49914
# [78]	validation_0-logloss:0.45870	validation_1-logloss:0.49817
# [79]	validation_0-logloss:0.45733	validation_1-logloss:0.49722
# [80]	validation_0-logloss:0.45600	validation_1-logloss:0.49634
# [81]	validation_0-logloss:0.45467	validation_1-logloss:0.49531
# [82]	validation_0-logloss:0.45336	validation_1-logloss:0.49442
# [83]	validation_0-logloss:0.45208	validation_1-logloss:0.49348
# [84]	validation_0-logloss:0.45081	validation_1-logloss:0.49261
# [85]	validation_0-logloss:0.44956	validation_1-logloss:0.49175
# [86]	validation_0-logloss:0.44834	validation_1-logloss:0.49095
# [87]	validation_0-logloss:0.44713	validation_1-logloss:0.49016
# [88]	validation_0-logloss:0.44593	validation_1-logloss:0.48926
# [89]	validation_0-logloss:0.44475	validation_1-logloss:0.48846
# [90]	validation_0-logloss:0.44358	validation_1-logloss:0.48767
# [91]	validation_0-logloss:0.44243	validation_1-logloss:0.48689
# [92]	validation_0-logloss:0.44131	validation_1-logloss:0.48618
# [93]	validation_0-logloss:0.44020	validation_1-logloss:0.48544
# [94]	validation_0-logloss:0.43911	validation_1-logloss:0.48474
# [95]	validation_0-logloss:0.43802	validation_1-logloss:0.48393
# [96]	validation_0-logloss:0.43696	validation_1-logloss:0.48316
# [97]	validation_0-logloss:0.43590	validation_1-logloss:0.48247
# [98]	validation_0-logloss:0.43486	validation_1-logloss:0.48178
# [99]	validation_0-logloss:0.43384	validation_1-logloss:0.48115
# [100]	validation_0-logloss:0.43283	validation_1-logloss:0.48049
# [101]	validation_0-logloss:0.43184	validation_1-logloss:0.47989
# [102]	validation_0-logloss:0.43085	validation_1-logloss:0.47916
# [103]	validation_0-logloss:0.42987	validation_1-logloss:0.47854
# [104]	validation_0-logloss:0.42892	validation_1-logloss:0.47787
# [105]	validation_0-logloss:0.42799	validation_1-logloss:0.47732
# [106]	validation_0-logloss:0.42708	validation_1-logloss:0.47673
# [107]	validation_0-logloss:0.42618	validation_1-logloss:0.47624
# [108]	validation_0-logloss:0.42527	validation_1-logloss:0.47554
# [109]	validation_0-logloss:0.42439	validation_1-logloss:0.47503
# [110]	validation_0-logloss:0.42352	validation_1-logloss:0.47453
# [111]	validation_0-logloss:0.42265	validation_1-logloss:0.47395
# [112]	validation_0-logloss:0.42182	validation_1-logloss:0.47351
# [113]	validation_0-logloss:0.42097	validation_1-logloss:0.47299
# [114]	validation_0-logloss:0.42015	validation_1-logloss:0.47247
# [115]	validation_0-logloss:0.41935	validation_1-logloss:0.47188
# [116]	validation_0-logloss:0.41856	validation_1-logloss:0.47129
# [117]	validation_0-logloss:0.41779	validation_1-logloss:0.47081
# [118]	validation_0-logloss:0.41703	validation_1-logloss:0.47033
# [119]	validation_0-logloss:0.41628	validation_1-logloss:0.46981
# [120]	validation_0-logloss:0.41553	validation_1-logloss:0.46934
# [121]	validation_0-logloss:0.41480	validation_1-logloss:0.46884
# [122]	validation_0-logloss:0.41409	validation_1-logloss:0.46844
# [123]	validation_0-logloss:0.41336	validation_1-logloss:0.46783
# [124]	validation_0-logloss:0.41266	validation_1-logloss:0.46741
# [125]	validation_0-logloss:0.41196	validation_1-logloss:0.46690
# [126]	validation_0-logloss:0.41128	validation_1-logloss:0.46649
# [127]	validation_0-logloss:0.41062	validation_1-logloss:0.46609
# [128]	validation_0-logloss:0.40994	validation_1-logloss:0.46553
# [129]	validation_0-logloss:0.40929	validation_1-logloss:0.46514
# [130]	validation_0-logloss:0.40863	validation_1-logloss:0.46468
# [131]	validation_0-logloss:0.40800	validation_1-logloss:0.46431
# [132]	validation_0-logloss:0.40736	validation_1-logloss:0.46386
# [133]	validation_0-logloss:0.40675	validation_1-logloss:0.46351
# [134]	validation_0-logloss:0.40614	validation_1-logloss:0.46316
# [135]	validation_0-logloss:0.40553	validation_1-logloss:0.46273
# [136]	validation_0-logloss:0.40494	validation_1-logloss:0.46240
# [137]	validation_0-logloss:0.40436	validation_1-logloss:0.46197
# [138]	validation_0-logloss:0.40377	validation_1-logloss:0.46157
# [139]	validation_0-logloss:0.40320	validation_1-logloss:0.46106
# [140]	validation_0-logloss:0.40263	validation_1-logloss:0.46067
# [141]	validation_0-logloss:0.40207	validation_1-logloss:0.46040
# [142]	validation_0-logloss:0.40152	validation_1-logloss:0.45991
# [143]	validation_0-logloss:0.40098	validation_1-logloss:0.45953
# [144]	validation_0-logloss:0.40043	validation_1-logloss:0.45921
# [145]	validation_0-logloss:0.39987	validation_1-logloss:0.45867
# [146]	validation_0-logloss:0.39932	validation_1-logloss:0.45813
# [147]	validation_0-logloss:0.39881	validation_1-logloss:0.45778
# [148]	validation_0-logloss:0.39829	validation_1-logloss:0.45745
# [149]	validation_0-logloss:0.39779	validation_1-logloss:0.45712
# [150]	validation_0-logloss:0.39726	validation_1-logloss:0.45667
# [151]	validation_0-logloss:0.39673	validation_1-logloss:0.45611
# [152]	validation_0-logloss:0.39622	validation_1-logloss:0.45556
# [153]	validation_0-logloss:0.39571	validation_1-logloss:0.45513
# [154]	validation_0-logloss:0.39522	validation_1-logloss:0.45471
# [155]	validation_0-logloss:0.39474	validation_1-logloss:0.45436
# [156]	validation_0-logloss:0.39426	validation_1-logloss:0.45402
# [157]	validation_0-logloss:0.39378	validation_1-logloss:0.45361
# [158]	validation_0-logloss:0.39330	validation_1-logloss:0.45311
# [159]	validation_0-logloss:0.39282	validation_1-logloss:0.45261
# [160]	validation_0-logloss:0.39238	validation_1-logloss:0.45229
# [161]	validation_0-logloss:0.39193	validation_1-logloss:0.45200
# [162]	validation_0-logloss:0.39149	validation_1-logloss:0.45170
# [163]	validation_0-logloss:0.39106	validation_1-logloss:0.45149
# [164]	validation_0-logloss:0.39060	validation_1-logloss:0.45105
# [165]	validation_0-logloss:0.39015	validation_1-logloss:0.45057
# [166]	validation_0-logloss:0.38972	validation_1-logloss:0.45013
# [167]	validation_0-logloss:0.38928	validation_1-logloss:0.44975
# [168]	validation_0-logloss:0.38886	validation_1-logloss:0.44935
# [169]	validation_0-logloss:0.38844	validation_1-logloss:0.44892
# [170]	validation_0-logloss:0.38802	validation_1-logloss:0.44851
# [171]	validation_0-logloss:0.38763	validation_1-logloss:0.44826
# [172]	validation_0-logloss:0.38722	validation_1-logloss:0.44806
# [173]	validation_0-logloss:0.38682	validation_1-logloss:0.44785
# [174]	validation_0-logloss:0.38643	validation_1-logloss:0.44773
# [175]	validation_0-logloss:0.38603	validation_1-logloss:0.44737
# [176]	validation_0-logloss:0.38565	validation_1-logloss:0.44723
# [177]	validation_0-logloss:0.38526	validation_1-logloss:0.44707
# [178]	validation_0-logloss:0.38489	validation_1-logloss:0.44692
# [179]	validation_0-logloss:0.38450	validation_1-logloss:0.44654
# [180]	validation_0-logloss:0.38414	validation_1-logloss:0.44640
# [181]	validation_0-logloss:0.38378	validation_1-logloss:0.44625
# [182]	validation_0-logloss:0.38342	validation_1-logloss:0.44612
# [183]	validation_0-logloss:0.38306	validation_1-logloss:0.44583
# [184]	validation_0-logloss:0.38271	validation_1-logloss:0.44570
# [185]	validation_0-logloss:0.38236	validation_1-logloss:0.44556
# [186]	validation_0-logloss:0.38202	validation_1-logloss:0.44553
# [187]	validation_0-logloss:0.38167	validation_1-logloss:0.44518
# [188]	validation_0-logloss:0.38133	validation_1-logloss:0.44492
# [189]	validation_0-logloss:0.38100	validation_1-logloss:0.44483
# [190]	validation_0-logloss:0.38068	validation_1-logloss:0.44481
# [191]	validation_0-logloss:0.38035	validation_1-logloss:0.44451
# [192]	validation_0-logloss:0.38004	validation_1-logloss:0.44430
# [193]	validation_0-logloss:0.37973	validation_1-logloss:0.44426
# [194]	validation_0-logloss:0.37942	validation_1-logloss:0.44419
# [195]	validation_0-logloss:0.37911	validation_1-logloss:0.44397
# [196]	validation_0-logloss:0.37881	validation_1-logloss:0.44391
# [197]	validation_0-logloss:0.37852	validation_1-logloss:0.44376
# [198]	validation_0-logloss:0.37822	validation_1-logloss:0.44362
# [199]	validation_0-logloss:0.37793	validation_1-logloss:0.44346
# [200]	validation_0-logloss:0.37765	validation_1-logloss:0.44335
# [201]	validation_0-logloss:0.37737	validation_1-logloss:0.44321
# [202]	validation_0-logloss:0.37708	validation_1-logloss:0.44305
# [203]	validation_0-logloss:0.37680	validation_1-logloss:0.44291
# [204]	validation_0-logloss:0.37653	validation_1-logloss:0.44277
# [205]	validation_0-logloss:0.37627	validation_1-logloss:0.44267
# [206]	validation_0-logloss:0.37600	validation_1-logloss:0.44255
# [207]	validation_0-logloss:0.37574	validation_1-logloss:0.44241
# [208]	validation_0-logloss:0.37548	validation_1-logloss:0.44230
# [209]	validation_0-logloss:0.37522	validation_1-logloss:0.44218
# [210]	validation_0-logloss:0.37496	validation_1-logloss:0.44201
# [211]	validation_0-logloss:0.37473	validation_1-logloss:0.44194
# [212]	validation_0-logloss:0.37448	validation_1-logloss:0.44194
# [213]	validation_0-logloss:0.37423	validation_1-logloss:0.44192
# [214]	validation_0-logloss:0.37401	validation_1-logloss:0.44186
# [215]	validation_0-logloss:0.37376	validation_1-logloss:0.44182
# [216]	validation_0-logloss:0.37354	validation_1-logloss:0.44180
# [217]	validation_0-logloss:0.37330	validation_1-logloss:0.44180
# [218]	validation_0-logloss:0.37305	validation_1-logloss:0.44174
# [219]	validation_0-logloss:0.37282	validation_1-logloss:0.44163
# [220]	validation_0-logloss:0.37259	validation_1-logloss:0.44164
# [221]	validation_0-logloss:0.37236	validation_1-logloss:0.44162
# [222]	validation_0-logloss:0.37213	validation_1-logloss:0.44161
# [223]	validation_0-logloss:0.37188	validation_1-logloss:0.44151
# [224]	validation_0-logloss:0.37161	validation_1-logloss:0.44136
# [225]	validation_0-logloss:0.37138	validation_1-logloss:0.44135
# [226]	validation_0-logloss:0.37113	validation_1-logloss:0.44125
# [227]	validation_0-logloss:0.37091	validation_1-logloss:0.44124
# [228]	validation_0-logloss:0.37067	validation_1-logloss:0.44119
# [229]	validation_0-logloss:0.37045	validation_1-logloss:0.44112
# [230]	validation_0-logloss:0.37020	validation_1-logloss:0.44105
# [231]	validation_0-logloss:0.36995	validation_1-logloss:0.44093
# [232]	validation_0-logloss:0.36975	validation_1-logloss:0.44093
# [233]	validation_0-logloss:0.36951	validation_1-logloss:0.44091
# [234]	validation_0-logloss:0.36930	validation_1-logloss:0.44087
# [235]	validation_0-logloss:0.36907	validation_1-logloss:0.44082
# [236]	validation_0-logloss:0.36884	validation_1-logloss:0.44076
# [237]	validation_0-logloss:0.36863	validation_1-logloss:0.44071
# [238]	validation_0-logloss:0.36841	validation_1-logloss:0.44070
# [239]	validation_0-logloss:0.36821	validation_1-logloss:0.44065
# [240]	validation_0-logloss:0.36799	validation_1-logloss:0.44062
# [241]	validation_0-logloss:0.36780	validation_1-logloss:0.44063
# [242]	validation_0-logloss:0.36756	validation_1-logloss:0.44049
# [243]	validation_0-logloss:0.36735	validation_1-logloss:0.44044
# [244]	validation_0-logloss:0.36711	validation_1-logloss:0.44032
# [245]	validation_0-logloss:0.36690	validation_1-logloss:0.44020
# [246]	validation_0-logloss:0.36670	validation_1-logloss:0.44015
# [247]	validation_0-logloss:0.36647	validation_1-logloss:0.44007
# [248]	validation_0-logloss:0.36627	validation_1-logloss:0.44001
# [249]	validation_0-logloss:0.36604	validation_1-logloss:0.43989
# [250]	validation_0-logloss:0.36585	validation_1-logloss:0.43986
# [251]	validation_0-logloss:0.36563	validation_1-logloss:0.43974
# [252]	validation_0-logloss:0.36544	validation_1-logloss:0.43970
# [253]	validation_0-logloss:0.36522	validation_1-logloss:0.43963
# [254]	validation_0-logloss:0.36504	validation_1-logloss:0.43954
# [255]	validation_0-logloss:0.36485	validation_1-logloss:0.43948
# [256]	validation_0-logloss:0.36464	validation_1-logloss:0.43940
# [257]	validation_0-logloss:0.36446	validation_1-logloss:0.43936
# [258]	validation_0-logloss:0.36425	validation_1-logloss:0.43925
# [259]	validation_0-logloss:0.36407	validation_1-logloss:0.43925
# [260]	validation_0-logloss:0.36387	validation_1-logloss:0.43915
# [261]	validation_0-logloss:0.36369	validation_1-logloss:0.43914
# [262]	validation_0-logloss:0.36349	validation_1-logloss:0.43904
# [263]	validation_0-logloss:0.36329	validation_1-logloss:0.43892
# [264]	validation_0-logloss:0.36312	validation_1-logloss:0.43893
# [265]	validation_0-logloss:0.36292	validation_1-logloss:0.43884
# [266]	validation_0-logloss:0.36276	validation_1-logloss:0.43880
# [267]	validation_0-logloss:0.36259	validation_1-logloss:0.43879
# [268]	validation_0-logloss:0.36243	validation_1-logloss:0.43874
# [269]	validation_0-logloss:0.36227	validation_1-logloss:0.43872
# [270]	validation_0-logloss:0.36210	validation_1-logloss:0.43873
# [271]	validation_0-logloss:0.36194	validation_1-logloss:0.43869
# [272]	validation_0-logloss:0.36179	validation_1-logloss:0.43870
# [273]	validation_0-logloss:0.36163	validation_1-logloss:0.43867
# [274]	validation_0-logloss:0.36148	validation_1-logloss:0.43864
# [275]	validation_0-logloss:0.36133	validation_1-logloss:0.43867
# [276]	validation_0-logloss:0.36118	validation_1-logloss:0.43864
# [277]	validation_0-logloss:0.36102	validation_1-logloss:0.43862
# [278]	validation_0-logloss:0.36088	validation_1-logloss:0.43863
# [279]	validation_0-logloss:0.36073	validation_1-logloss:0.43861
# [280]	validation_0-logloss:0.36058	validation_1-logloss:0.43858
# [281]	validation_0-logloss:0.36043	validation_1-logloss:0.43861
# [282]	validation_0-logloss:0.36029	validation_1-logloss:0.43864
# [283]	validation_0-logloss:0.36014	validation_1-logloss:0.43862
# [284]	validation_0-logloss:0.36001	validation_1-logloss:0.43865
# [285]	validation_0-logloss:0.35986	validation_1-logloss:0.43867
# [286]	validation_0-logloss:0.35973	validation_1-logloss:0.43866
# [287]	validation_0-logloss:0.35960	validation_1-logloss:0.43867
# [288]	validation_0-logloss:0.35946	validation_1-logloss:0.43865
# [289]	validation_0-logloss:0.35932	validation_1-logloss:0.43866
# [290]	validation_0-logloss:0.35919	validation_1-logloss:0.43868
# [291]	validation_0-logloss:0.35904	validation_1-logloss:0.43882
# [292]	validation_0-logloss:0.35890	validation_1-logloss:0.43881
# [293]	validation_0-logloss:0.35877	validation_1-logloss:0.43883
# [294]	validation_0-logloss:0.35862	validation_1-logloss:0.43898
# [295]	validation_0-logloss:0.35849	validation_1-logloss:0.43897
# [296]	validation_0-logloss:0.35836	validation_1-logloss:0.43899
# [297]	validation_0-logloss:0.35823	validation_1-logloss:0.43900
# [298]	validation_0-logloss:0.35811	validation_1-logloss:0.43901
# [299]	validation_0-logloss:0.35800	validation_1-logloss:0.43902
# [300]	validation_0-logloss:0.35788	validation_1-logloss:0.43901
# [301]	validation_0-logloss:0.35774	validation_1-logloss:0.43916
# [302]	validation_0-logloss:0.35759	validation_1-logloss:0.43911
# [303]	validation_0-logloss:0.35748	validation_1-logloss:0.43911
# [304]	validation_0-logloss:0.35737	validation_1-logloss:0.43913
# [305]	validation_0-logloss:0.35723	validation_1-logloss:0.43908
# [306]	validation_0-logloss:0.35712	validation_1-logloss:0.43910
# [307]	validation_0-logloss:0.35698	validation_1-logloss:0.43904
# [308]	validation_0-logloss:0.35687	validation_1-logloss:0.43905
# [309]	validation_0-logloss:0.35677	validation_1-logloss:0.43907
# [310]	validation_0-logloss:0.35664	validation_1-logloss:0.43903
# [311]	validation_0-logloss:0.35653	validation_1-logloss:0.43905
# [312]	validation_0-logloss:0.35643	validation_1-logloss:0.43907
# [313]	validation_0-logloss:0.35630	validation_1-logloss:0.43902
# [314]	validation_0-logloss:0.35620	validation_1-logloss:0.43904
# [315]	validation_0-logloss:0.35607	validation_1-logloss:0.43899
# [316]	validation_0-logloss:0.35597	validation_1-logloss:0.43901
# [317]	validation_0-logloss:0.35588	validation_1-logloss:0.43903
# [318]	validation_0-logloss:0.35578	validation_1-logloss:0.43898
# [319]	validation_0-logloss:0.35568	validation_1-logloss:0.43900
# [320]	validation_0-logloss:0.35559	validation_1-logloss:0.43902
# [321]	validation_0-logloss:0.35549	validation_1-logloss:0.43897
# [322]	validation_0-logloss:0.35540	validation_1-logloss:0.43899
# [323]	validation_0-logloss:0.35531	validation_1-logloss:0.43901
# [324]	validation_0-logloss:0.35522	validation_1-logloss:0.43903
# [325]	validation_0-logloss:0.35513	validation_1-logloss:0.43902
# [326]	validation_0-logloss:0.35504	validation_1-logloss:0.43904
# [327]	validation_0-logloss:0.35496	validation_1-logloss:0.43907
# [328]	validation_0-logloss:0.35486	validation_1-logloss:0.43899
# [329]	validation_0-logloss:0.35478	validation_1-logloss:0.43902
# 0.7777777777777778

# %%
solutions = {}

for row in test_df.iter_rows(named=True):
	id = row["PassengerId"]
	x = tfr.transform(pl.DataFrame(row))
	solutions[id] = model3.predict(x)

with open(file="./submission.csv", mode="w") as f:
	f.write("PassengerId,Survived\n")
	for k in solutions.keys():
		f.write(f"{k},{int(solutions[k][0])}\n")

# %%
sss = StratifiedShuffleSplit(n_splits=1, random_state=42)

param_grid = {
	"n_estimators": [1400, 1500, 1700],
	"learning_rate": [0.01, 0.02]
}

for train_index, test_index in sss.split(X, y):
	X_train, X_test = X[train_index], X[test_index]
	y_train, y_test = y[train_index], y[test_index]

	opt = GridSearchCV(
		estimator=model,
		param_grid=param_grid,
		cv=5,
		verbose=True
	).fit(X_train, y_train)
print(opt.best_estimator_.score(X_test, y_test))
print(opt.best_params_)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# 0.7777777777777778
# {'learning_rate': 0.01, 'n_estimators': 1500}

# %%
solutions = {}

for row in test_df.iter_rows(named=True):
	id = row["PassengerId"]
	x = tfr.transform(pl.DataFrame(row))
	solutions[id] = opt.best_estimator_.predict(x)

with open(file="./submission.csv", mode="w") as f:
	f.write("PassengerId,Survived\n")
	for k in solutions.keys():
		f.write(f"{k},{int(solutions[k][0])}\n")
# Out:
# 0.8222222222222222
# {'learning_rate': 0.01, 'n_estimators': 1500}
